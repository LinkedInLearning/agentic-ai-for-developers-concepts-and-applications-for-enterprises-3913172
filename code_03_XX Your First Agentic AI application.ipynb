# %% [markdown]
# ### 03.03. Setting up Indexes

# %%
#Install prerequisite packages
# !pip install python-dotenv==1.0.0

# !pip install llama-index==0.10.59
# !pip install llama-index-llms-openai==0.1.27
# !pip install llama-index-embeddings-openai==0.1.11
# !pip install llama-index-llms-azure-openai==0.1.10
# !pip install llama-index-embeddings-azure-openai==0.1.11
# Out:
# Requirement already satisfied: python-dotenv==1.0.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (1.0.0)
# Requirement already satisfied: llama-index==0.10.59 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (0.10.59)
# Requirement already satisfied: llama-index-agent-openai<0.3.0,>=0.1.4 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index==0.10.59) (0.2.9)
# Requirement already satisfied: llama-index-cli<0.2.0,>=0.1.2 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index==0.10.59) (0.1.13)
# Requirement already satisfied: llama-index-core==0.10.59 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index==0.10.59) (0.10.59)
# Requirement already satisfied: llama-index-embeddings-openai<0.2.0,>=0.1.5 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index==0.10.59) (0.1.11)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.2.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index==0.10.59) (0.2.7)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index==0.10.59) (0.9.48)
# Requirement already satisfied: llama-index-llms-openai<0.2.0,>=0.1.27 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index==0.10.59) (0.1.27)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.2.0,>=0.1.3 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index==0.10.59) (0.1.8)
# Requirement already satisfied: llama-index-program-openai<0.2.0,>=0.1.3 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index==0.10.59) (0.1.7)
# Requirement already satisfied: llama-index-question-gen-openai<0.2.0,>=0.1.2 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index==0.10.59) (0.1.3)
# Requirement already satisfied: llama-index-readers-file<0.2.0,>=0.1.4 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index==0.10.59) (0.1.32)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.1.2 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index==0.10.59) (0.1.6)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core==0.10.59->llama-index==0.10.59) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core==0.10.59->llama-index==0.10.59) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core==0.10.59->llama-index==0.10.59) (3.10.0)
# Requirement already satisfied: dataclasses-json in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core==0.10.59->llama-index==0.10.59) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core==0.10.59->llama-index==0.10.59) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core==0.10.59->llama-index==0.10.59) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core==0.10.59->llama-index==0.10.59) (2024.6.1)
# Requirement already satisfied: httpx in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core==0.10.59->llama-index==0.10.59) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core==0.10.59->llama-index==0.10.59) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core==0.10.59->llama-index==0.10.59) (3.3)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core==0.10.59->llama-index==0.10.59) (3.8.1)
# Requirement already satisfied: numpy<2.0.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core==0.10.59->llama-index==0.10.59) (1.26.4)
# Requirement already satisfied: openai>=1.1.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core==0.10.59->llama-index==0.10.59) (1.38.0)
# Requirement already satisfied: pandas in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core==0.10.59->llama-index==0.10.59) (2.2.2)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core==0.10.59->llama-index==0.10.59) (10.4.0)
# Requirement already satisfied: requests>=2.31.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core==0.10.59->llama-index==0.10.59) (2.32.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core==0.10.59->llama-index==0.10.59) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core==0.10.59->llama-index==0.10.59) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core==0.10.59->llama-index==0.10.59) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core==0.10.59->llama-index==0.10.59) (4.11.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core==0.10.59->llama-index==0.10.59) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core==0.10.59->llama-index==0.10.59) (1.16.0)
# Requirement already satisfied: llama-cloud>=0.0.11 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-indices-managed-llama-cloud>=0.2.0->llama-index==0.10.59) (0.0.11)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index==0.10.59) (4.12.3)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index==0.10.59) (4.3.1)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index==0.10.59) (0.0.26)
# Requirement already satisfied: llama-parse>=0.4.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-readers-llama-parse>=0.1.2->llama-index==0.10.59) (0.4.9)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.59->llama-index==0.10.59) (2.3.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.59->llama-index==0.10.59) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.59->llama-index==0.10.59) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.59->llama-index==0.10.59) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.59->llama-index==0.10.59) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.59->llama-index==0.10.59) (1.9.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.2.0,>=0.1.4->llama-index==0.10.59) (2.5)
# Requirement already satisfied: pydantic>=1.10 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-cloud>=0.0.11->llama-index-indices-managed-llama-cloud>=0.2.0->llama-index==0.10.59) (2.8.2)
# Requirement already satisfied: anyio in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from httpx->llama-index-core==0.10.59->llama-index==0.10.59) (4.2.0)
# Requirement already satisfied: certifi in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from httpx->llama-index-core==0.10.59->llama-index==0.10.59) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from httpx->llama-index-core==0.10.59->llama-index==0.10.59) (1.0.5)
# Requirement already satisfied: idna in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from httpx->llama-index-core==0.10.59->llama-index==0.10.59) (3.7)
# Requirement already satisfied: sniffio in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from httpx->llama-index-core==0.10.59->llama-index==0.10.59) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from httpcore==1.*->httpx->llama-index-core==0.10.59->llama-index==0.10.59) (0.14.0)
# Requirement already satisfied: click in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.59->llama-index==0.10.59) (8.1.7)
# Requirement already satisfied: joblib in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.59->llama-index==0.10.59) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.59->llama-index==0.10.59) (2024.7.24)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from openai>=1.1.0->llama-index-core==0.10.59->llama-index==0.10.59) (1.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from requests>=2.31.0->llama-index-core==0.10.59->llama-index==0.10.59) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from requests>=2.31.0->llama-index-core==0.10.59->llama-index==0.10.59) (2.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core==0.10.59->llama-index==0.10.59) (3.0.3)
# Requirement already satisfied: colorama in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core==0.10.59->llama-index==0.10.59) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core==0.10.59->llama-index==0.10.59) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from dataclasses-json->llama-index-core==0.10.59->llama-index==0.10.59) (3.21.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from pandas->llama-index-core==0.10.59->llama-index==0.10.59) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from pandas->llama-index-core==0.10.59->llama-index==0.10.59) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from pandas->llama-index-core==0.10.59->llama-index==0.10.59) (2024.1)
# Requirement already satisfied: packaging>=17.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core==0.10.59->llama-index==0.10.59) (23.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from pydantic>=1.10->llama-cloud>=0.0.11->llama-index-indices-managed-llama-cloud>=0.2.0->llama-index==0.10.59) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from pydantic>=1.10->llama-cloud>=0.0.11->llama-index-indices-managed-llama-cloud>=0.2.0->llama-index==0.10.59) (2.20.1)
# Requirement already satisfied: six>=1.5 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core==0.10.59->llama-index==0.10.59) (1.16.0)
# Requirement already satisfied: llama-index-llms-openai==0.1.27 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (0.1.27)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.57 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-llms-openai==0.1.27) (0.10.59)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (3.10.0)
# Requirement already satisfied: dataclasses-json in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (2024.6.1)
# Requirement already satisfied: httpx in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (3.3)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (3.8.1)
# Requirement already satisfied: numpy<2.0.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (1.26.4)
# Requirement already satisfied: openai>=1.1.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (1.38.0)
# Requirement already satisfied: pandas in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (2.2.2)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (10.4.0)
# Requirement already satisfied: requests>=2.31.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (2.32.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (4.11.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (2.3.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (1.9.4)
# Requirement already satisfied: click in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (8.1.7)
# Requirement already satisfied: joblib in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (2024.7.24)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (1.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (2.8.2)
# Requirement already satisfied: sniffio in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (1.3.0)
# Requirement already satisfied: certifi in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (1.0.5)
# Requirement already satisfied: idna in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (2.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (3.0.3)
# Requirement already satisfied: colorama in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (3.21.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (2024.1)
# Requirement already satisfied: packaging>=17.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (23.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (2.20.1)
# Requirement already satisfied: six>=1.5 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai==0.1.27) (1.16.0)
# Requirement already satisfied: llama-index-embeddings-openai==0.1.11 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (0.1.11)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-embeddings-openai==0.1.11) (0.10.59)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (3.10.0)
# Requirement already satisfied: dataclasses-json in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (2024.6.1)
# Requirement already satisfied: httpx in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (3.3)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (3.8.1)
# Requirement already satisfied: numpy<2.0.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (1.26.4)
# Requirement already satisfied: openai>=1.1.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (1.38.0)
# Requirement already satisfied: pandas in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (2.2.2)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (10.4.0)
# Requirement already satisfied: requests>=2.31.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (2.32.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (4.11.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (2.3.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (1.9.4)
# Requirement already satisfied: click in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (8.1.7)
# Requirement already satisfied: joblib in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (2024.7.24)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (1.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (2.8.2)
# Requirement already satisfied: sniffio in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (1.3.0)
# Requirement already satisfied: certifi in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (1.0.5)
# Requirement already satisfied: idna in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (2.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (3.0.3)
# Requirement already satisfied: colorama in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (3.21.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (2024.1)
# Requirement already satisfied: packaging>=17.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (23.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (2.20.1)
# Requirement already satisfied: six>=1.5 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai==0.1.11) (1.16.0)
# Requirement already satisfied: llama-index-llms-azure-openai==0.1.10 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (0.1.10)
# Requirement already satisfied: azure-identity<2.0.0,>=1.15.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-llms-azure-openai==0.1.10) (1.17.1)
# Requirement already satisfied: httpx in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-llms-azure-openai==0.1.10) (0.27.0)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.11.post1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-llms-azure-openai==0.1.10) (0.10.59)
# Requirement already satisfied: llama-index-llms-openai<0.2.0,>=0.1.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-llms-azure-openai==0.1.10) (0.1.27)
# Requirement already satisfied: azure-core>=1.23.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai==0.1.10) (1.30.2)
# Requirement already satisfied: cryptography>=2.5 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai==0.1.10) (43.0.0)
# Requirement already satisfied: msal>=1.24.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai==0.1.10) (1.30.0)
# Requirement already satisfied: msal-extensions>=0.3.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai==0.1.10) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai==0.1.10) (4.11.0)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (3.10.0)
# Requirement already satisfied: dataclasses-json in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (2024.6.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (3.3)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (3.8.1)
# Requirement already satisfied: numpy<2.0.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (1.26.4)
# Requirement already satisfied: openai>=1.1.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (1.38.0)
# Requirement already satisfied: pandas in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (2.2.2)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (10.4.0)
# Requirement already satisfied: requests>=2.31.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (2.32.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (4.66.5)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (1.16.0)
# Requirement already satisfied: anyio in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from httpx->llama-index-llms-azure-openai==0.1.10) (4.2.0)
# Requirement already satisfied: certifi in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from httpx->llama-index-llms-azure-openai==0.1.10) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from httpx->llama-index-llms-azure-openai==0.1.10) (1.0.5)
# Requirement already satisfied: idna in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from httpx->llama-index-llms-azure-openai==0.1.10) (3.7)
# Requirement already satisfied: sniffio in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from httpx->llama-index-llms-azure-openai==0.1.10) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from httpcore==1.*->httpx->llama-index-llms-azure-openai==0.1.10) (0.14.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (2.3.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (1.9.4)
# Requirement already satisfied: six>=1.11.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from azure-core>=1.23.0->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai==0.1.10) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from cryptography>=2.5->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai==0.1.10) (1.16.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.24.0->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai==0.1.10) (2.9.0)
# Requirement already satisfied: portalocker<3,>=1.4 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from msal-extensions>=0.3.0->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai==0.1.10) (2.10.1)
# Requirement already satisfied: click in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (8.1.7)
# Requirement already satisfied: joblib in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (2024.7.24)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (1.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (2.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (3.0.3)
# Requirement already satisfied: colorama in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (3.21.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (2024.1)
# Requirement already satisfied: pycparser in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai==0.1.10) (2.21)
# Requirement already satisfied: packaging>=17.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (23.2)
# Requirement already satisfied: pywin32>=226 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from portalocker<3,>=1.4->msal-extensions>=0.3.0->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai==0.1.10) (305.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-llms-azure-openai==0.1.10) (2.20.1)
# Requirement already satisfied: llama-index-embeddings-azure-openai==0.1.11 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (0.1.11)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.11.post1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-embeddings-azure-openai==0.1.11) (0.10.59)
# Requirement already satisfied: llama-index-embeddings-openai<0.2.0,>=0.1.3 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-embeddings-azure-openai==0.1.11) (0.1.11)
# Requirement already satisfied: llama-index-llms-azure-openai<0.2.0,>=0.1.3 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-embeddings-azure-openai==0.1.11) (0.1.10)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (3.10.0)
# Requirement already satisfied: dataclasses-json in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (2024.6.1)
# Requirement already satisfied: httpx in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (3.3)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (3.8.1)
# Requirement already satisfied: numpy<2.0.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (1.26.4)
# Requirement already satisfied: openai>=1.1.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (1.38.0)
# Requirement already satisfied: pandas in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (2.2.2)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (10.4.0)
# Requirement already satisfied: requests>=2.31.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (2.32.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (4.11.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (1.16.0)
# Requirement already satisfied: azure-identity<2.0.0,>=1.15.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-llms-azure-openai<0.2.0,>=0.1.3->llama-index-embeddings-azure-openai==0.1.11) (1.17.1)
# Requirement already satisfied: llama-index-llms-openai<0.2.0,>=0.1.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from llama-index-llms-azure-openai<0.2.0,>=0.1.3->llama-index-embeddings-azure-openai==0.1.11) (0.1.27)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (2.3.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (1.9.4)
# Requirement already satisfied: azure-core>=1.23.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai<0.2.0,>=0.1.3->llama-index-embeddings-azure-openai==0.1.11) (1.30.2)
# Requirement already satisfied: cryptography>=2.5 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai<0.2.0,>=0.1.3->llama-index-embeddings-azure-openai==0.1.11) (43.0.0)
# Requirement already satisfied: msal>=1.24.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai<0.2.0,>=0.1.3->llama-index-embeddings-azure-openai==0.1.11) (1.30.0)
# Requirement already satisfied: msal-extensions>=0.3.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai<0.2.0,>=0.1.3->llama-index-embeddings-azure-openai==0.1.11) (1.2.0)
# Requirement already satisfied: click in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (8.1.7)
# Requirement already satisfied: joblib in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (2024.7.24)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (1.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (2.8.2)
# Requirement already satisfied: sniffio in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (1.3.0)
# Requirement already satisfied: certifi in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (1.0.5)
# Requirement already satisfied: idna in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (2.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (3.0.3)
# Requirement already satisfied: colorama in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (3.21.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (2024.1)
# Requirement already satisfied: six>=1.11.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from azure-core>=1.23.0->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai<0.2.0,>=0.1.3->llama-index-embeddings-azure-openai==0.1.11) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from cryptography>=2.5->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai<0.2.0,>=0.1.3->llama-index-embeddings-azure-openai==0.1.11) (1.16.0)
# Requirement already satisfied: packaging>=17.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (23.2)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.24.0->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai<0.2.0,>=0.1.3->llama-index-embeddings-azure-openai==0.1.11) (2.9.0)
# Requirement already satisfied: portalocker<3,>=1.4 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from msal-extensions>=0.3.0->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai<0.2.0,>=0.1.3->llama-index-embeddings-azure-openai==0.1.11) (2.10.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-embeddings-azure-openai==0.1.11) (2.20.1)
# Requirement already satisfied: pycparser in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai<0.2.0,>=0.1.3->llama-index-embeddings-azure-openai==0.1.11) (2.21)
# Requirement already satisfied: pywin32>=226 in c:\users\kumar\anaconda3\envs\spark\lib\site-packages (from portalocker<3,>=1.4->msal-extensions>=0.3.0->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai<0.2.0,>=0.1.3->llama-index-embeddings-azure-openai==0.1.11) (305.1)

# %%
#Setup Azure Open AI connection
from llama_index.llms.azure_openai import AzureOpenAI
from llama_index.embeddings.azure_openai import AzureOpenAIEmbedding

from llama_index.core import Settings
import os
import nest_asyncio

nest_asyncio.apply()

api_key = "e638bb3ebcb84b79aa5b6f93d6e6503a"
azure_endpoint = "https://agentic-ai-course-account.openai.azure.com/"
api_version = "2024-05-01-preview"

Settings.llm=AzureOpenAI(
    model="gpt-35-turbo",
    deployment_name="agentai-gpt35",
    api_key=api_key,
    azure_endpoint=azure_endpoint,
    api_version=api_version,
)

Settings.embed_model= AzureOpenAIEmbedding(
    model="text-embedding-ada-002",
    deployment_name="agentai-embedding",
    api_key=api_key,
    azure_endpoint=azure_endpoint,
    api_version=api_version,
)

# %%
#Create indexes for vector search
from llama_index.core import SimpleDirectoryReader
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core import  VectorStoreIndex

splitter=SentenceSplitter(chunk_size=1024)

#-------------------------------------------------------------------
#Setup NoSQL document index
#-------------------------------------------------------------------
nosql_documents=SimpleDirectoryReader(
    input_files=["Evaluating NoSQL databases for OLAP workloads.pdf"])\
            .load_data()

#Read documents into nodes
nosql_nodes=splitter.get_nodes_from_documents(nosql_documents)
#Create a vector Store
nosql_index=VectorStoreIndex(nosql_nodes)
#Create a query engine
nosql_query_engine = nosql_index.as_query_engine()

#-------------------------------------------------------------------
#Setup NLP document index
#-------------------------------------------------------------------
nlp_documents=SimpleDirectoryReader(
    input_files=["Software Infrastructure for natural language processing.pdf"])\
            .load_data()
#Read documents into nodes
nlp_nodes=splitter.get_nodes_from_documents(nlp_documents)
#Create a vector Store
nlp_index=VectorStoreIndex(nlp_nodes)
#Create a query engine
nlp_query_engine = nlp_index.as_query_engine()

# %% [markdown]
# ### 03.04. Setup the Agentic Router

# %%
from llama_index.core.tools import QueryEngineTool
from llama_index.core.query_engine.router_query_engine import RouterQueryEngine
from llama_index.core.selectors import LLMSingleSelector

#Create a query engine Tool for NoSQL
nosql_tool = QueryEngineTool.from_defaults(
    query_engine=nosql_query_engine,
    name="Evaluate NoSQL Databases",
    description=(
        "Evaluate NoSQL databases for OLAP use cases."
    ),
)

#Create a query engine Tool for NLP
nlp_tool = QueryEngineTool.from_defaults(
    query_engine=nlp_query_engine,
    name="Software infra for NLP",
    description=(
        "Software infrastructure for natural language processing."
    ),
)

#Create a Router Agent. Provide the Tools to the Agent
query_engine=RouterQueryEngine(
    selector=LLMSingleSelector.from_defaults(),
    query_engine_tools=[
        nosql_tool,
        nlp_tool,
    ],
    verbose=True
)

# %% [markdown]
# ### 03.05. Route with Agentic AI

# %%
#Ask a question about NoSQL
response = query_engine.query("What data processing components were used for NoSQL evaluation?")
print(str(response))
# Out:
# Selecting query engine 0: The first choice specifically mentions evaluating NoSQL databases, which is directly relevant to the question about data processing components used for NoSQL evaluation..
# The data processing components used for NoSQL evaluation were Apache HDFS and Apache Spark. The raw data was loaded into HDFS and then transformed using PySpark before being loaded into the NoSQL databases.

# %%
response = query_engine.query("What are the key elements of GATE design?")
print(str(response))
# Out:
# Selecting query engine 1: The key elements of GATE design involve natural language processing, so the software infrastructure for natural language processing is the most relevant choice..
# GATE comprises three principal elements in its design: GDM, the GATE Document Manager, CREOLE, a Collection of Reusable Objects for Language Engineering, and GGI, the GATE Graphical Interface. These elements correspond to the three key objectives identified in the paper. GDM provides a central repository for storing all information generated by an LE system, CREOLE modules or objects do the real work of analyzing texts, and GGI encapsulates GDM and CREOLE resources for interactive building and testing of LE components and systems.
